# %% [markdown]
# # Crypto Website API Project

# %%
# this code is provided by coinmarketcap website from their API documentation

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15', # limit the rows to 15, original is 5000
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data) # did not include this to display data due to github
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
import pandas as pd

pd.set_option('display.max_columns', None) # this line will enable all columns to be displayed
pd.set_option('display.max_rows', None)  # this line will enable all rows to be displayed

# %%
# displaying the data, the correct way. not the display in line 1

df = pd.json_normalize(data['data']) # assign this df to variable 'df'

df['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)

df
# Out:
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\811682172.py:5: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
#       id          name symbol                  slug  num_market_pairs  \
# 0      1       Bitcoin    BTC               bitcoin             10341
# 1   1027      Ethereum    ETH              ethereum              7109
# 2    825        Tether   USDT                tether             56775
# 3   1839           BNB    BNB                   bnb              1497
# 4   3408      USD Coin   USDC              usd-coin             13290
# 5     52           XRP    XRP                   xrp               983
# 6   2010       Cardano    ADA               cardano               867
# ...

# %%
# creating a function for automated running of api
# pasted the same code in box 1

def api_runner():
    global df # declaring df as global variable
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15', # limit the rows to 15, original is 5000
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }
    
    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data) # did not include this to display data due to github
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    df2 = pd.json_normalize(data['data']) # assign new variable 'df2'
    df2['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
    df = df.append(df2) # appending the updated data from 'df2' to the original 'df'
    
    # these next lines create the csv file
    if not os.path.isfile(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv'): # if this file does not exist then proceed to next line
        df.to_csv(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv', header='column_names') # saving the file as csv
    else # if it exists then next line
        df.to_csv(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv', mode = 'a' , header=False) # append the data not overwrite 'a' stands for append

# %%
# importing more time libraries
# testing if the automated API run

import os
from time import time
from time import sleep

for i in range(333): # 333 limit runs per day, that's why range is 333
    api_runner()
    print('API ran successfully')
    sleep(60) #sleep for 1 minute then run again
exit()
# Out:
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\3365325975.py:28: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df2['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\3365325975.py:29: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2) # appending the updated data from 'df2' to the original 'df'
# API ran successfully
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\3365325975.py:28: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
# ...

# %%
# display df, to check if the new df is updating per timestamp

df

# confirmed updating, i ran it 3 times with 1 minute in between
# Out:
#       id          name symbol                  slug  num_market_pairs  \
# 0      1       Bitcoin    BTC               bitcoin             10341
# 1   1027      Ethereum    ETH              ethereum              7109
# 2    825        Tether   USDT                tether             56775
# 3   1839           BNB    BNB                   bnb              1497
# 4   3408      USD Coin   USDC              usd-coin             13290
# 5     52           XRP    XRP                   xrp               983
# 6   2010       Cardano    ADA               cardano               867
# 7     74      Dogecoin   DOGE              dogecoin               741
# 8   5426        Solana    SOL                solana               485
# 9      2      Litecoin    LTC              litecoin               945
# 10  1958          TRON    TRX                  tron               786
# 11  3890       Polygon  MATIC               polygon               771
# ...

# %%
# this time saving the csv file
# creating a function for automated running of api
# pasted the same code in box 1

def api_runner():
    global df # declaring df as global variable
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15', # limit the rows to 15, original is 5000
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }
    
    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data) # did not include this to display data due to github
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    
    # had to revert back to original variable 'df'
    # df2 is not necessary for the final procedure
    
    df = pd.json_normalize(data['data']) # assign new variable 'df'
    df['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
    df
    
    # these next lines create the csv file
    if not os.path.isfile(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv'): # if this file does not exist then proceed to next line
        df.to_csv(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv', header='column_names') # saving the file as csv
    else: # if it exists then next line
        df.to_csv(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv', mode='a' , header=False) # append the data not overwrite 'a' stands for append

# %%
# running the function above with csv file saving

import os
from time import time
from time import sleep

for i in range(333): # 333 limit runs per day, that's why range is 333
    api_runner() # calling the function
    print('API ran successfully') # just to print if it runs
    sleep(60) #sleep for 1 minute then run again
exit()
# Out:
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\978347248.py:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
# API ran successfully
# C:\Users\Dash\AppData\Local\Temp\ipykernel_7984\978347248.py:32: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now') # create a new column 'timestamp' to be used every time we pull the data (for automated process)
# API ran successfully
# ...

# %%
# calling in to read the csv file

read_df = pd.read_csv(r'C:\Users\Dash\Desktop\DA\My Portfolio\API.csv')
read_df
# Out:
#     Unnamed: 0    id          name symbol                  slug  \
# 0            0     1       Bitcoin    BTC               bitcoin
# 1            1  1027      Ethereum    ETH              ethereum
# 2            2   825        Tether   USDT                tether
# 3            3  1839           BNB    BNB                   bnb
# 4            4  3408      USD Coin   USDC              usd-coin
# 5            5    52           XRP    XRP                   xrp
# 6            6  2010       Cardano    ADA               cardano
# 7            7    74      Dogecoin   DOGE              dogecoin
# 8            8  5426        Solana    SOL                solana
# 9            9     2      Litecoin    LTC              litecoin
# 10          10  1958          TRON    TRX                  tron
# 11          11  3890       Polygon  MATIC               polygon
# 12          12  6636      Polkadot    DOT          polkadot-new
# 13          13  1831  Bitcoin Cash    BCH          bitcoin-cash
# ...
